# %% [markdown]
# The aim of this notebook is to test the implementation by using TS to optimize the
# Alpine2 function.
#
# ## Setup

# %%
import torch
from torch import Tensor
from botorch.models import SingleTaskGP
from botorch.test_functions import SyntheticTestFunction
from botorch.acquisition import PosteriorMean
from botorch.optim import optimize_acqf
from gpytorch.mlls import ExactMarginalLogLikelihood
from gpytorch.utils.errors import NotPSDError
from botorch import fit_gpytorch_model
from gp_sampling.decoupled_samplers import decoupled_sampler
from gp_sampling.thompson_samplers import decoupled_ts, exact_ts
from typing import Optional, Union
import math
from botorch.models.transforms import Standardize
# %matplotlib
import matplotlib.pyplot as plt
from time import time
# Out:
# Using matplotlib backend: TkAgg

# %%
class Alpine2(SyntheticTestFunction):
    """
    The Alpine-2 test function.

    n-dimensional function typically evaluated on x_i in [0, 10].
    This implementation is rescaled to [0, 1].

    A(x) = - prod_{i=1}^n sqrt(x_i) sin(x_i).
        (negated to make it into a minimization problem by default)
    Scaled (w/ x_i in [0, 1]):
    A(x) = - prod_{i=1}^n sqrt(10 * x_i) sin(10 * x_i)

    The global optimum is found at x_i ≈ 7.91705268466621...
    Rescaled: 0.7917052...
    """

    def __init__(
        self, dim=6, noise_std: Optional[float] = None, negate: bool = False
    ) -> None:
        self.dim = dim
        self._bounds = [(0.0, 1.0) for _ in range(self.dim)]
        self._optimizers = [tuple(0.791705268466621 for _ in range(self.dim))]
        self._optimal_value = -math.pow(2.808130979537964, self.dim)
        super().__init__(noise_std=noise_std, negate=negate)

    def evaluate_true(self, X: Tensor) -> Tensor:
        X = 10 * X
        return -torch.prod(torch.sqrt(X) * torch.sin(X), dim=-1, keepdim=True)

# %%
def run_one_replication(
    iterations: int,
    dim: int,
    num_draws: int = 2 ** 6,
    q: int = 1,
    num_basis: int = 2 ** 8,
    decoupled: bool = True,
    seed: Optional[int] = None,
    device: Optional[Union[torch.device, str]] = None
) -> Tensor:
    r"""
    Runs one replication of BO using TS to optimize Alpine2 function.

    Args:
        iterations: Number of iterations
        dim: Dimension of the problem
        num_draws: Number of samples to use for TS
        q: Number of parallel evaluations
        num_basis: Number of basis functions to use for decoupled sampler
        decoupled: If True, uses decoupled sampler. Otherwise, samples from exact GP.
        seed: The seed for random number generation
        device: Option to specify cpu / gpu. If not decoupled, defaults to GPU if
        available. For decoupled, defaults to CPU.

    Returns:
        An `iterations+1` tensor of output performance. Evaluated as the function value
            at the maximizer of PosteriorMean.
    """
    if device is None:
        if decoupled:
            device = torch.device("cpu")
        else:
            device = (
                torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
            )
    else:
        device = torch.device(device) if isinstance(device, str) else device
    if seed is not None:
        torch.manual_seed(seed)
    function = Alpine2(dim=dim)
    bounds = torch.tensor([[0.], [1.]], device=device).repeat(1, dim)
    train_X = torch.rand(2*dim + 2, 2, device=device)
    train_Y = function(train_X).reshape(-1, 1)

    def current_best() -> Tensor:
        r"""
        Returns the current best solution value, evaluated as the true function value
        at the maximizer of PosteriorMean

        Returns:
            A tensor with the current best value
        """
        pm = PosteriorMean(model)
        current_best_point, _ = optimize_acqf(
            acq_function=pm,
            bounds=bounds,
            q=1,
            num_restarts=10*dim,
            raw_samples=200*dim
        )
        return function.evaluate_true(current_best_point).reshape(-1)

    def update_gp() -> SingleTaskGP:
        r"""
        Updates (refits) the GP model using the most recent data

        Returns:
            The fitted GP model
        """
        gp = SingleTaskGP(train_X, train_Y, outcome_transform=Standardize(m=1))
        mll = ExactMarginalLogLikelihood(gp.likelihood, gp)
        fit_gpytorch_model(mll)
        return gp

    output = torch.empty(iterations+1, device=device)
    for i in range(iterations):
        iter_start = time()
        # fit the gp and get the current performance
        model = update_gp()
        output[i] = current_best()
        if decoupled:
            # draw the thompson sample using decoupled sampler
            ps = decoupled_sampler(model=model, sample_shape=[q], num_basis=num_basis)
            next_sample = decoupled_ts(ps, num_draws=num_draws, d=dim)
        else:
            # draw the thompson sample using exact posterior
            next_sample = exact_ts(model, num_draws=num_draws, d=dim)
        next_eval = function(next_sample).reshape(-1, 1)
        train_X = torch.cat([train_X, next_sample])
        train_Y = torch.cat([train_Y, next_eval])
        print("iter %d with decoupled %s took %s" % (i, decoupled, time()-iter_start))

    # add the final performance after all observations
    model = update_gp()
    output[-1] = current_best()
    return output

# %% [markdown]
# Run a comparison of TS and EI on the 2d Alpine2 problem.

# %%
replications = 5
iterations = 100
dim = 2
decoupled_out = torch.zeros(replications, iterations+1)
exact_out = torch.zeros(replications, iterations+1)
run_decoupled = True
run_exact = False
executed = torch.ones(replications, dtype=torch.long)
for i in range(replications):
    try:
        if run_decoupled:
            decoupled_out[i] = run_one_replication(
                iterations, dim, decoupled=True, seed=i
            )
        if run_exact:
            exact_out[i] = run_one_replication(iterations, dim, decoupled=False, seed=i)
    except:
        executed[i] = 0

executed = executed.to(dtype=torch.bool)
plt.plot(torch.mean(decoupled_out[executed], dim=0), label="decoupled TS")
plt.plot(torch.mean(exact_out[executed], dim=0), label="exact TS")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# iter 0 with decoupled True took 0.2744104862213135
# iter 1 with decoupled True took 0.1883692741394043
# iter 2 with decoupled True took 0.13054990768432617
# iter 3 with decoupled True took 0.25389599800109863
# iter 4 with decoupled True took 0.30435657501220703
# iter 5 with decoupled True took 0.19256329536437988
# iter 6 with decoupled True took 0.2754495143890381
# iter 7 with decoupled True took 0.22202754020690918
# iter 8 with decoupled True took 0.18460774421691895
# iter 9 with decoupled True took 0.2535064220428467
# iter 10 with decoupled True took 0.18195414543151855
# iter 11 with decoupled True took 0.17594075202941895
# iter 12 with decoupled True took 0.2707939147949219
# iter 13 with decoupled True took 0.16854596138000488
# iter 14 with decoupled True took 0.26456618309020996
# iter 15 with decoupled True took 0.1369328498840332
# iter 16 with decoupled True took 0.12177371978759766
# iter 17 with decoupled True took 0.1909172534942627
# iter 18 with decoupled True took 0.33026885986328125
# iter 19 with decoupled True took 0.22939610481262207
# iter 20 with decoupled True took 0.28781962394714355
# iter 21 with decoupled True took 0.23895502090454102
# iter 22 with decoupled True took 0.627199649810791
# iter 23 with decoupled True took 0.3338909149169922
# iter 24 with decoupled True took 0.21343231201171875
# iter 25 with decoupled True took 0.32824182510375977
# iter 26 with decoupled True took 0.2355351448059082
# iter 27 with decoupled True took 0.1435995101928711
# iter 28 with decoupled True took 0.4376347064971924
# iter 29 with decoupled True took 0.2951817512512207
# iter 30 with decoupled True took 0.446087121963501
# iter 31 with decoupled True took 0.2314438819885254
# iter 32 with decoupled True took 0.35047030448913574
# iter 33 with decoupled True took 0.36821913719177246
# iter 34 with decoupled True took 0.2767782211303711
# iter 35 with decoupled True took 0.26526832580566406
# iter 36 with decoupled True took 0.26784801483154297
# iter 37 with decoupled True took 0.15040826797485352
# iter 38 with decoupled True took 0.111572265625
# iter 39 with decoupled True took 0.11732769012451172
# iter 40 with decoupled True took 0.34581851959228516
# iter 41 with decoupled True took 0.30533909797668457
# iter 42 with decoupled True took 0.24518656730651855
# iter 43 with decoupled True took 0.1261138916015625
# iter 44 with decoupled True took 0.11157965660095215
# iter 45 with decoupled True took 0.31749629974365234
# iter 46 with decoupled True took 0.21758794784545898
# iter 47 with decoupled True took 0.25797414779663086
# iter 48 with decoupled True took 0.27676939964294434
# iter 49 with decoupled True took 0.1916048526763916
# iter 50 with decoupled True took 0.11903214454650879
# iter 51 with decoupled True took 0.13564634323120117
# iter 52 with decoupled True took 0.24758481979370117
# iter 53 with decoupled True took 0.12950634956359863
# iter 54 with decoupled True took 0.19242382049560547
# iter 55 with decoupled True took 0.32918524742126465
# iter 56 with decoupled True took 0.34719419479370117
# iter 57 with decoupled True took 0.6811830997467041
# iter 58 with decoupled True took 0.2535538673400879
# iter 59 with decoupled True took 0.21271514892578125
# iter 60 with decoupled True took 0.12713956832885742
# iter 61 with decoupled True took 0.3185596466064453
# iter 62 with decoupled True took 0.159379243850708
# iter 63 with decoupled True took 0.11397123336791992
# iter 64 with decoupled True took 0.5303564071655273
# iter 65 with decoupled True took 0.32692670822143555
# iter 66 with decoupled True took 0.43172144889831543
# iter 67 with decoupled True took 0.4370694160461426
# iter 68 with decoupled True took 0.27994298934936523
# iter 69 with decoupled True took 0.13914775848388672
# iter 70 with decoupled True took 0.27779054641723633
# iter 71 with decoupled True took 0.2549283504486084
# iter 72 with decoupled True took 0.13654804229736328
# iter 73 with decoupled True took 0.13489031791687012
# iter 74 with decoupled True took 0.1435103416442871
# iter 75 with decoupled True took 0.1597604751586914
# iter 76 with decoupled True took 0.12804436683654785
# iter 77 with decoupled True took 0.2785985469818115
# iter 78 with decoupled True took 0.20656991004943848
# iter 79 with decoupled True took 0.1867678165435791
# iter 80 with decoupled True took 0.25237345695495605
# iter 81 with decoupled True took 0.1325075626373291
# iter 82 with decoupled True took 0.14703369140625
# iter 83 with decoupled True took 0.15810155868530273
# iter 84 with decoupled True took 0.19142699241638184
# iter 85 with decoupled True took 0.18988752365112305
# iter 86 with decoupled True took 0.13399338722229004
# iter 87 with decoupled True took 0.3382375240325928
# iter 88 with decoupled True took 0.14153194427490234
# iter 89 with decoupled True took 0.3625614643096924
# iter 90 with decoupled True took 0.1722276210784912
# iter 91 with decoupled True took 0.24153852462768555
# iter 92 with decoupled True took 0.2641942501068115
# iter 93 with decoupled True took 0.32222509384155273
# iter 94 with decoupled True took 0.18569517135620117
# iter 95 with decoupled True took 0.1452486515045166
# iter 96 with decoupled True took 0.16132426261901855
# iter 97 with decoupled True took 0.3181722164154053
# iter 98 with decoupled True took 0.40273523330688477
# iter 99 with decoupled True took 0.1637098789215088
# iter 0 with decoupled True took 0.32268404960632324
# iter 1 with decoupled True took 0.22658252716064453
# iter 2 with decoupled True took 0.3214380741119385
# iter 3 with decoupled True took 0.36518263816833496
# iter 4 with decoupled True took 0.47492146492004395
# iter 5 with decoupled True took 0.524799108505249
# iter 6 with decoupled True took 0.4430818557739258
# iter 7 with decoupled True took 0.32703089714050293
# iter 8 with decoupled True took 0.262498140335083
# iter 9 with decoupled True took 0.19347167015075684
# iter 10 with decoupled True took 0.3244590759277344
# iter 11 with decoupled True took 0.2682168483734131
# iter 12 with decoupled True took 0.17719030380249023
# iter 13 with decoupled True took 0.2358226776123047
# iter 14 with decoupled True took 0.2681088447570801
# iter 15 with decoupled True took 0.2016923427581787
# iter 16 with decoupled True took 0.26193714141845703
# iter 17 with decoupled True took 0.26337122917175293
# iter 18 with decoupled True took 0.1420459747314453
# iter 19 with decoupled True took 0.3404347896575928
# iter 20 with decoupled True took 0.36464357376098633
# iter 21 with decoupled True took 0.32531070709228516
# iter 22 with decoupled True took 0.47840094566345215
# iter 23 with decoupled True took 0.5262212753295898
# iter 24 with decoupled True took 0.5318131446838379
# iter 25 with decoupled True took 0.3442521095275879
# iter 26 with decoupled True took 0.20883893966674805
# iter 27 with decoupled True took 0.2968125343322754
# iter 28 with decoupled True took 0.18353271484375
# iter 29 with decoupled True took 0.24513769149780273
# iter 30 with decoupled True took 0.2749314308166504
# iter 31 with decoupled True took 0.33858537673950195
# iter 32 with decoupled True took 0.3599376678466797
# iter 33 with decoupled True took 0.274381160736084
# iter 34 with decoupled True took 0.21491432189941406
# iter 35 with decoupled True took 0.21630024909973145
# iter 36 with decoupled True took 0.1826469898223877
# iter 37 with decoupled True took 0.20867919921875
# iter 38 with decoupled True took 0.20980572700500488
# iter 39 with decoupled True took 0.567777156829834
# iter 40 with decoupled True took 0.11484003067016602
# iter 41 with decoupled True took 0.1683187484741211
# iter 42 with decoupled True took 0.28867006301879883
# iter 43 with decoupled True took 0.1284503936767578
# iter 44 with decoupled True took 0.3721938133239746
# iter 45 with decoupled True took 0.27102160453796387
# iter 46 with decoupled True took 0.23715710639953613
# iter 47 with decoupled True took 0.3313589096069336
# iter 48 with decoupled True took 0.13630366325378418
# iter 49 with decoupled True took 0.11725926399230957
# iter 50 with decoupled True took 0.1361539363861084
# iter 51 with decoupled True took 0.20020222663879395
# iter 52 with decoupled True took 0.1270747184753418
# iter 53 with decoupled True took 0.4253265857696533
# iter 54 with decoupled True took 0.12085366249084473
# iter 55 with decoupled True took 0.12835454940795898
# iter 56 with decoupled True took 0.1242215633392334
# iter 57 with decoupled True took 0.12423419952392578
# iter 58 with decoupled True took 0.11198258399963379
# iter 59 with decoupled True took 0.24268507957458496
# iter 60 with decoupled True took 0.12184500694274902
# iter 61 with decoupled True took 0.19658827781677246
# iter 62 with decoupled True took 0.6732144355773926
# iter 63 with decoupled True took 0.47876906394958496
# iter 64 with decoupled True took 0.12510085105895996
# iter 65 with decoupled True took 0.23036789894104004
# iter 66 with decoupled True took 0.14229393005371094
# iter 67 with decoupled True took 0.24635529518127441
# iter 68 with decoupled True took 0.8081939220428467
# iter 69 with decoupled True took 0.29520750045776367
# iter 70 with decoupled True took 0.2921638488769531
# iter 71 with decoupled True took 0.26452207565307617
# iter 72 with decoupled True took 0.14407134056091309
# iter 73 with decoupled True took 0.13441205024719238
# iter 74 with decoupled True took 0.1827080249786377
# iter 75 with decoupled True took 0.11278653144836426
# iter 76 with decoupled True took 0.1421198844909668
# iter 77 with decoupled True took 0.40797853469848633
# iter 78 with decoupled True took 0.2279071807861328
# iter 79 with decoupled True took 0.15982818603515625
# iter 80 with decoupled True took 0.24628019332885742
# iter 81 with decoupled True took 0.44894886016845703
# iter 82 with decoupled True took 0.27792811393737793
# iter 83 with decoupled True took 0.14499711990356445
# iter 84 with decoupled True took 0.30210423469543457
# iter 85 with decoupled True took 0.275313138961792
# iter 86 with decoupled True took 0.13227534294128418
# iter 87 with decoupled True took 0.13280105590820312
# iter 88 with decoupled True took 0.14257311820983887
# iter 89 with decoupled True took 0.2389051914215088
# iter 90 with decoupled True took 0.2255086898803711
# iter 91 with decoupled True took 0.13104724884033203
# iter 92 with decoupled True took 0.1429738998413086
# iter 93 with decoupled True took 0.15361523628234863
# iter 94 with decoupled True took 0.3886759281158447
# iter 95 with decoupled True took 0.15588784217834473
# iter 96 with decoupled True took 0.2953784465789795
# iter 97 with decoupled True took 0.1531214714050293
# iter 98 with decoupled True took 0.17150521278381348
# iter 99 with decoupled True took 0.1582953929901123
# iter 0 with decoupled True took 0.1713118553161621
# iter 1 with decoupled True took 0.27545905113220215
# iter 2 with decoupled True took 0.1542670726776123
# iter 3 with decoupled True took 0.27976250648498535
# iter 4 with decoupled True took 0.12772440910339355
# iter 5 with decoupled True took 0.18913507461547852
# iter 6 with decoupled True took 0.14441633224487305
# iter 7 with decoupled True took 0.18527007102966309
# iter 8 with decoupled True took 0.2660653591156006
# iter 9 with decoupled True took 0.29201436042785645
# iter 10 with decoupled True took 0.15136957168579102
# iter 11 with decoupled True took 0.36194896697998047
# iter 12 with decoupled True took 0.4666109085083008
# iter 13 with decoupled True took 0.3492767810821533
# iter 14 with decoupled True took 0.5779271125793457
# iter 15 with decoupled True took 0.6982154846191406
# iter 16 with decoupled True took 0.3680558204650879
# iter 17 with decoupled True took 0.6043977737426758
# iter 18 with decoupled True took 0.6245312690734863
# iter 19 with decoupled True took 0.45873188972473145
# iter 20 with decoupled True took 0.47599291801452637
# iter 21 with decoupled True took 0.3521885871887207
# iter 22 with decoupled True took 0.35449981689453125
# iter 23 with decoupled True took 0.4388716220855713
# iter 24 with decoupled True took 0.5696089267730713
# iter 25 with decoupled True took 0.33701419830322266
# iter 26 with decoupled True took 0.39022207260131836
# iter 27 with decoupled True took 0.32158708572387695
# iter 28 with decoupled True took 0.3700287342071533
# iter 29 with decoupled True took 0.375821590423584
# iter 30 with decoupled True took 0.24665594100952148
# iter 31 with decoupled True took 0.23245835304260254
# iter 32 with decoupled True took 0.3361971378326416
# iter 33 with decoupled True took 0.40035343170166016
# iter 34 with decoupled True took 0.35297417640686035
# iter 35 with decoupled True took 0.48642635345458984
# iter 36 with decoupled True took 0.25615715980529785
# iter 37 with decoupled True took 0.3248269557952881
# iter 38 with decoupled True took 0.27657508850097656
# iter 39 with decoupled True took 0.32811784744262695
# iter 40 with decoupled True took 0.28955864906311035
# iter 41 with decoupled True took 0.27186083793640137
# iter 42 with decoupled True took 0.28076791763305664
# iter 43 with decoupled True took 0.30921006202697754
# iter 44 with decoupled True took 0.41175031661987305
# iter 45 with decoupled True took 0.4252347946166992
# iter 46 with decoupled True took 0.2992830276489258
# iter 47 with decoupled True took 0.2322986125946045
# iter 48 with decoupled True took 0.36945080757141113
# iter 49 with decoupled True took 0.3066232204437256
# iter 50 with decoupled True took 0.3301682472229004
# iter 51 with decoupled True took 0.37813425064086914
# iter 52 with decoupled True took 0.27660441398620605
# iter 53 with decoupled True took 0.34589385986328125
# iter 54 with decoupled True took 0.4155557155609131
# iter 55 with decoupled True took 0.3097367286682129
# iter 56 with decoupled True took 0.3174135684967041
# iter 57 with decoupled True took 0.3172750473022461
# iter 58 with decoupled True took 0.23153448104858398
# iter 59 with decoupled True took 0.3036534786224365
# iter 60 with decoupled True took 0.356428861618042
# iter 61 with decoupled True took 0.2969069480895996
# iter 62 with decoupled True took 0.24744462966918945
# iter 63 with decoupled True took 0.3224163055419922
# iter 64 with decoupled True took 0.23159527778625488
# iter 65 with decoupled True took 0.4043762683868408
# iter 66 with decoupled True took 0.3379361629486084
# iter 67 with decoupled True took 0.24473929405212402
# iter 68 with decoupled True took 0.42453551292419434
# iter 69 with decoupled True took 0.5077364444732666
# iter 70 with decoupled True took 0.2928624153137207
# iter 71 with decoupled True took 0.3053090572357178
# iter 72 with decoupled True took 0.475980281829834
# iter 73 with decoupled True took 0.2217543125152588
# iter 74 with decoupled True took 0.39320874214172363
# iter 75 with decoupled True took 0.30144357681274414
# iter 76 with decoupled True took 0.3917858600616455
# iter 77 with decoupled True took 0.3921322822570801
# iter 78 with decoupled True took 0.39197540283203125
# iter 79 with decoupled True took 0.2616896629333496
# iter 80 with decoupled True took 0.3499338626861572
# iter 81 with decoupled True took 0.42102622985839844
# iter 82 with decoupled True took 0.2830932140350342
# iter 83 with decoupled True took 0.38860368728637695
# iter 84 with decoupled True took 0.27072787284851074
# iter 85 with decoupled True took 0.2906162738800049
# iter 86 with decoupled True took 0.33370232582092285
# iter 87 with decoupled True took 0.35776400566101074
# iter 88 with decoupled True took 0.3032238483428955
# iter 89 with decoupled True took 0.26172757148742676
# iter 90 with decoupled True took 0.29176902770996094
# iter 91 with decoupled True took 0.3817024230957031
# iter 92 with decoupled True took 0.2704048156738281
# iter 93 with decoupled True took 0.4855070114135742
# iter 94 with decoupled True took 0.2673947811126709
# iter 95 with decoupled True took 0.26111698150634766
# iter 96 with decoupled True took 0.37427544593811035
# iter 97 with decoupled True took 0.26116204261779785
# iter 98 with decoupled True took 0.27716851234436035
# iter 99 with decoupled True took 0.3099837303161621
# iter 0 with decoupled True took 0.3421299457550049
# iter 1 with decoupled True took 0.1523149013519287
# iter 2 with decoupled True took 0.19333696365356445
# iter 3 with decoupled True took 0.2940480709075928
# iter 4 with decoupled True took 0.2576611042022705
# iter 5 with decoupled True took 0.36947178840637207
# iter 6 with decoupled True took 0.23340916633605957
# iter 7 with decoupled True took 0.41399216651916504
# iter 8 with decoupled True took 0.22609686851501465
# iter 9 with decoupled True took 0.281951904296875
# iter 10 with decoupled True took 0.4013857841491699
# iter 11 with decoupled True took 0.1926097869873047
# iter 12 with decoupled True took 0.22012734413146973
# iter 13 with decoupled True took 0.1960008144378662
# iter 14 with decoupled True took 0.27556467056274414
# iter 15 with decoupled True took 0.24898958206176758
# iter 16 with decoupled True took 0.3402135372161865
# iter 17 with decoupled True took 0.2832314968109131
# iter 18 with decoupled True took 0.22604084014892578
# iter 19 with decoupled True took 0.19649577140808105
# iter 20 with decoupled True took 0.4012737274169922
# iter 21 with decoupled True took 0.2675669193267822
# iter 22 with decoupled True took 0.19791531562805176
# iter 23 with decoupled True took 0.34237098693847656
# iter 24 with decoupled True took 0.32081007957458496
# iter 25 with decoupled True took 0.2524988651275635
# iter 26 with decoupled True took 0.11100959777832031
# iter 27 with decoupled True took 0.26778221130371094
# iter 28 with decoupled True took 0.2639193534851074
# iter 29 with decoupled True took 0.5455260276794434
# iter 30 with decoupled True took 0.20906472206115723
# iter 31 with decoupled True took 0.32768750190734863
# iter 32 with decoupled True took 0.19837522506713867
# iter 33 with decoupled True took 0.2966642379760742
# iter 34 with decoupled True took 0.22760295867919922
# iter 35 with decoupled True took 0.10513424873352051
# iter 36 with decoupled True took 0.22881317138671875
# iter 37 with decoupled True took 0.3499031066894531
# iter 38 with decoupled True took 0.10457873344421387
# iter 39 with decoupled True took 0.24387335777282715
# iter 40 with decoupled True took 0.24940848350524902
# iter 41 with decoupled True took 0.3583071231842041
# iter 42 with decoupled True took 0.2168276309967041
# iter 43 with decoupled True took 0.3382878303527832
# iter 44 with decoupled True took 0.2807631492614746
# iter 45 with decoupled True took 0.2521195411682129
# iter 46 with decoupled True took 0.26868462562561035
# iter 47 with decoupled True took 0.408599853515625
# iter 48 with decoupled True took 0.4401378631591797
# iter 49 with decoupled True took 0.12286639213562012
# iter 50 with decoupled True took 0.45078039169311523
# iter 51 with decoupled True took 0.2830343246459961
# iter 52 with decoupled True took 0.41242384910583496
# iter 53 with decoupled True took 0.31316304206848145
# iter 54 with decoupled True took 0.3017995357513428
# iter 55 with decoupled True took 0.36741018295288086
# iter 56 with decoupled True took 0.2229146957397461
# iter 57 with decoupled True took 0.22214174270629883
# iter 58 with decoupled True took 0.14548897743225098
# iter 59 with decoupled True took 0.5552959442138672
# iter 60 with decoupled True took 0.21106338500976562
# iter 61 with decoupled True took 0.28783202171325684
# iter 62 with decoupled True took 0.3216278553009033
# iter 63 with decoupled True took 0.3916454315185547
# iter 64 with decoupled True took 0.4066002368927002
# iter 65 with decoupled True took 0.36484456062316895
# iter 66 with decoupled True took 0.3597683906555176
# iter 67 with decoupled True took 0.2629401683807373
# iter 68 with decoupled True took 0.21811437606811523
# iter 69 with decoupled True took 0.25140976905822754
# iter 70 with decoupled True took 0.3743114471435547
# iter 71 with decoupled True took 0.36901116371154785
# iter 72 with decoupled True took 0.34213900566101074
# iter 73 with decoupled True took 0.26569581031799316
# iter 74 with decoupled True took 0.1220541000366211
# iter 75 with decoupled True took 0.32779526710510254
# iter 76 with decoupled True took 0.42127490043640137
# iter 77 with decoupled True took 0.30962514877319336
# iter 78 with decoupled True took 0.42727041244506836
# iter 79 with decoupled True took 0.2391526699066162
# iter 80 with decoupled True took 0.2904345989227295
# iter 81 with decoupled True took 0.2770266532897949
# iter 82 with decoupled True took 0.1954212188720703
# iter 83 with decoupled True took 0.4687020778656006
# iter 84 with decoupled True took 0.4691276550292969
# iter 85 with decoupled True took 0.2753746509552002
# iter 86 with decoupled True took 0.31449031829833984
# iter 87 with decoupled True took 0.5374116897583008
# iter 88 with decoupled True took 0.2665870189666748
# iter 89 with decoupled True took 0.37885141372680664
# iter 90 with decoupled True took 0.2334737777709961
# iter 91 with decoupled True took 0.3709104061126709
# iter 92 with decoupled True took 0.20331478118896484
# iter 93 with decoupled True took 0.37773990631103516
# iter 94 with decoupled True took 0.27445197105407715
# iter 95 with decoupled True took 0.26236724853515625
# iter 96 with decoupled True took 0.32010769844055176
# iter 97 with decoupled True took 0.25266456604003906
# iter 98 with decoupled True took 0.347470760345459
# iter 99 with decoupled True took 0.3690781593322754
# iter 0 with decoupled True took 0.17066454887390137
# iter 1 with decoupled True took 0.19639182090759277
# iter 2 with decoupled True took 0.16426372528076172
# iter 3 with decoupled True took 0.21848082542419434
# iter 4 with decoupled True took 0.2753121852874756
# iter 5 with decoupled True took 0.3112068176269531
# iter 6 with decoupled True took 0.33731770515441895
# iter 7 with decoupled True took 0.3566880226135254
# iter 8 with decoupled True took 0.15412235260009766
# iter 9 with decoupled True took 0.21705055236816406
# iter 10 with decoupled True took 0.18251538276672363
# iter 11 with decoupled True took 0.3837416172027588
# iter 12 with decoupled True took 0.24889898300170898
# iter 13 with decoupled True took 0.3304104804992676
# iter 14 with decoupled True took 0.24480891227722168
# iter 15 with decoupled True took 0.24164104461669922
# iter 16 with decoupled True took 0.1462085247039795
# iter 17 with decoupled True took 0.41651272773742676
# iter 18 with decoupled True took 0.46591806411743164
# iter 19 with decoupled True took 0.5765883922576904
# iter 20 with decoupled True took 0.6227445602416992
# iter 21 with decoupled True took 0.4882662296295166
# iter 22 with decoupled True took 0.5720419883728027
# iter 23 with decoupled True took 0.40931248664855957
# iter 24 with decoupled True took 0.38553810119628906
# iter 25 with decoupled True took 0.6565847396850586
# iter 26 with decoupled True took 0.35210442543029785
# iter 27 with decoupled True took 0.4346776008605957
# iter 28 with decoupled True took 0.5333659648895264
# iter 29 with decoupled True took 0.3242974281311035
# iter 30 with decoupled True took 0.6130969524383545
# iter 31 with decoupled True took 0.5425429344177246
# iter 32 with decoupled True took 0.3369557857513428
# iter 33 with decoupled True took 0.4165773391723633
# iter 34 with decoupled True took 0.24645113945007324
# iter 35 with decoupled True took 0.31339240074157715
# iter 36 with decoupled True took 0.3163900375366211
# iter 37 with decoupled True took 0.313934326171875
# iter 38 with decoupled True took 0.24918389320373535
# iter 39 with decoupled True took 0.3252403736114502
# iter 40 with decoupled True took 0.33188629150390625
# iter 41 with decoupled True took 0.3184843063354492
# iter 42 with decoupled True took 0.2678718566894531
# iter 43 with decoupled True took 0.31723785400390625
# iter 44 with decoupled True took 0.42827844619750977
# iter 45 with decoupled True took 0.2799956798553467
# iter 46 with decoupled True took 0.315021276473999
# iter 47 with decoupled True took 0.37545108795166016
# iter 48 with decoupled True took 0.31937646865844727
# iter 49 with decoupled True took 0.3116495609283447
# iter 50 with decoupled True took 0.2613821029663086
# iter 51 with decoupled True took 0.28148627281188965
# iter 52 with decoupled True took 0.40611958503723145
# iter 53 with decoupled True took 0.46674346923828125
# iter 54 with decoupled True took 0.43901824951171875
# iter 55 with decoupled True took 0.4451901912689209
# iter 56 with decoupled True took 0.366382360458374
# iter 57 with decoupled True took 0.35504913330078125
# iter 58 with decoupled True took 0.3489203453063965
# iter 59 with decoupled True took 0.3287086486816406
# iter 60 with decoupled True took 0.2883296012878418
# iter 61 with decoupled True took 0.3531787395477295
# iter 62 with decoupled True took 0.30425262451171875
# iter 63 with decoupled True took 0.26459193229675293
# iter 64 with decoupled True took 0.11835741996765137
# iter 65 with decoupled True took 0.3686501979827881
# iter 66 with decoupled True took 0.3348855972290039
# iter 67 with decoupled True took 0.22685551643371582
# iter 68 with decoupled True took 0.28421640396118164
# iter 69 with decoupled True took 0.4848194122314453
# iter 70 with decoupled True took 0.3857717514038086
# iter 71 with decoupled True took 0.3351137638092041
# iter 72 with decoupled True took 0.3439643383026123
# iter 73 with decoupled True took 0.259965181350708
# iter 74 with decoupled True took 0.38034534454345703
# iter 75 with decoupled True took 0.1824188232421875
# iter 76 with decoupled True took 0.37587475776672363
# iter 77 with decoupled True took 0.22481489181518555
# iter 78 with decoupled True took 0.32652711868286133
# iter 79 with decoupled True took 0.2650947570800781
# iter 80 with decoupled True took 0.28287243843078613
# iter 81 with decoupled True took 0.20224285125732422
# iter 82 with decoupled True took 0.3099539279937744
# iter 83 with decoupled True took 0.3390190601348877
# iter 84 with decoupled True took 0.2626004219055176
# iter 85 with decoupled True took 0.3875763416290283
# iter 86 with decoupled True took 0.2556459903717041
# iter 87 with decoupled True took 0.3233468532562256
# iter 88 with decoupled True took 0.5132393836975098
# iter 89 with decoupled True took 0.31418347358703613
# iter 90 with decoupled True took 0.48961758613586426
# iter 91 with decoupled True took 0.2841193675994873
# iter 92 with decoupled True took 0.4455118179321289
# iter 93 with decoupled True took 0.4092733860015869
# iter 94 with decoupled True took 0.25663089752197266
# iter 95 with decoupled True took 0.36174488067626953
# iter 96 with decoupled True took 0.5981907844543457
# iter 97 with decoupled True took 0.3025698661804199
# iter 98 with decoupled True took 0.3845059871673584
# iter 99 with decoupled True took 0.35360169410705566
